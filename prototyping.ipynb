# %%
import pandas as pd

df_raw = pd.read_excel('originals/Raw international financial data_FY22-25.xlsx', sheet_name='FY25 Mar Est - Europe (2)')

# %%
df_raw
# Out:
#                                 Europe           Unnamed: 1 Unnamed: 2  \
# 0               FY 2025 March Estimate                  NaN        NaN
# 1                                  NaN                  NaN        NaN
# 2                                  NaN                  NaN        NaN
# 3                                  NaN                  NaN        NaN
# 4                                  NaN                  NaN        NaN
# ..                                 ...                  ...        ...
# 517                                NaN  Germany - S51 Total        NaN
# 518        Dept. 195 - Reimbursements                 Spain        NaN
# 519                                NaN          Spain Total        NaN
# 520  Dept. 195 - Reimbursements  Total                  NaN        NaN
# 521                        Grand Total                  NaN        143
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...
